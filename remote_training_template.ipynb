# %%
exp = !!!exp!!!
branch = !!!branch!!!

# %%
# %cd ~
# !git clone https://github.com/huggingface/peft
# %cd ~/peft
# !pip install -e .
# !echo  $patch | git apply
# %cd ~

# %%
# %cd ~
# !git clone https://github.com/huggingface/peft
# %cd ~/peft
# !pip install -e .
# !git status
# !git apply ~/molecule-retrieval-using-nlp/peft_forward.patch
# !git status
# %cd ~

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
github_token = user_secrets.get_secret("github_token")
gitrepo = user_secrets.get_secret("gitrepo")
uname_git = user_secrets.get_secret("uname_git")
wandb_api_key = user_secrets.get_secret("wandb_api_key")
kaggle_uname = user_secrets.get_secret("kaggle_uname")
kaggle_token = user_secrets.get_secret("kaggle_token")

# %cd ~
# !git clone https://$uname_git:$github_token@github.com/$gitrepo
# %cd molecule-retrieval-using-nlp
# !git checkout data
# !tar zxvf data.tar.gz >/dev/null
# !git checkout $branch

# !pip install torch_geometric >/dev/null
# !pip install wandb >/dev/null


# %env KAGGLE_USERNAME=$kaggle_uname >/dev/null
# %env KAGGLE_KEY=$kaggle_token >/dev/null
# !wandb login $wandb_api_key

# %%
# !tar -xzf /kaggle/input/altegrad23-processed-distilbert-base-uncased/processed_distilbert-base-uncased.tgz
# !ls __data

# %%
# !git checkout $branch

# %%
# !python train.py -e $exp

# %%
# !tar -cvzf /kaggle/working/output.tgz __output
